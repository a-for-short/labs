# %%
#%matplotlib ipympl
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.signal import savgol_filter

# %%
a = pd.read_csv('20241003-123636.txt', delimiter='\t')
a.columns = ['time', 'T0', 'T1', 'T2', 'T3']

# %%
for i in range(4):
    plt.plot(a['time'], a[f'T{i}'])
plt.xlabel('time')
plt.ylabel('T')
# Out:
# Text(0, 0.5, 'T')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for i in range(4):
    T0_diff = np.diff(savgol_filter(a['T0'], 11, 10))
    t_diff = np.diff(a['time'])

# %%
plt.scatter(a['time'][1:], T0_diff)
